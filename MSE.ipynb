# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,30,100)

# %%
y = 200* x + 3*np.random.randint(-100,100,100)

# %%
plt.scatter(x,y)

# %%
def f(x,a,b):
    return a*x + b

# %%
from scipy.optimize import curve_fit

# %%
popt , pcov = curve_fit(f,x,y)

# %%
a , b = popt

# %%
plt.scatter(x,y)
plt.plot(x, a*x + b, "r")

# %%
a*35 + b
# Out:
# 6979.0989088854267

# %%
def g(x):
    return a*x+b#預測含數

# %%
g(35)
# Out:
# 6979.0989088854267

# %%
from sklearn.cross_validation import train_test_split#可以隨機取檢驗和訓練資料的功能

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size = 0.2,random_state = 1)

# %%
popt , pcov = curve_fit(f,xtrain,ytrain)

# %%
a , b = popt

# %%
plt.scatter(xtest,ytest)
plt.plot(xtest, a*xtest + b, "r")#檢測test的狀況

# %%
MSE = (xtest , a*xtest+b)**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-36459ceb8ce2> in <module>()
# ----> 1 MSE = (xtest , a*xtest+b)**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'tuple' and 'int'

# %%
MSE = np.sum((ytest - (a*xtest+b))**2)/ len(xtest)#算預測與實際的誤差

# %%
MSE
# Out:
# 29454.788695221527

# %%
mset= np.sum((ytrain - (a*xtrain+b))**2)/ len(xtrain)

# %%
mset
# Out:
# 27487.054100206773

# %%
def k(x,a,b):
    return np.sin(a*x) + b*x

y = np.sin(x*2.4)+3.9*x+0.57*np.random.randint(-3,59,100)

# %%
plt.scatter(x,y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size = 0.2,random_state = 1)

# %%
popt , pcov = curve_fit(k,xtrain,ytrain,p0=[2.5,4.0])

# %%
a , b = popt

# %%
plt.scatter(xtest,ytest)
plt.plot(xtest, np.sin(a*xtest) + b*xtest, "r")

# %%
MSE2 = np.sum((ytest - (a*xtest+b))**2)/ len(xtest)#算預測與實際的誤差

# %%
MSE2
# Out:
# 1406.948401042423

# %%
a
# Out:
# 2.4625432690489562

# %%
b
# Out:
# 4.6460709919195544
